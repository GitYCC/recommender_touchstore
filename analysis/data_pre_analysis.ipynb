# %% [markdown]
# # Data Pre-analysis

# %%
# %matplotlib inline

import os
from pprint import pprint
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


DIR_DATA =  os.path.join('..', 'data')

# %%
df_ratings = pd.read_csv(os.path.join(DIR_DATA, 'ratings_pub.csv'))
df_movies = pd.read_csv(os.path.join(DIR_DATA, 'movies_pub.csv'))
df_genome = pd.read_csv(os.path.join(DIR_DATA, 'genome_pub.csv'))
df_tags = pd.read_csv(os.path.join(DIR_DATA, 'tags_pub.csv'))

# %% [markdown]
# ## ratings
#
# * User Ids: MovieLens users were selected at random for inclusion. Their ids have been anonymized. User ids are consistent between ratings.csv and tags.csv (i.e., the same id refers to the same user across the two files).
# * Movie Ids: Only movies with at least one rating or tag are included in the dataset. These movie ids are consistent with those used on the MovieLens web site (e.g., id 1 corresponds to the URL https://movielens.org/movies/1). Movie ids are consistent between ratings.csv, tags.csv, movies.csv, and links.csv (i.e., the same id refers to the same movie across these four data files).
# * Ratings Data File Structure:
#     * Ratings are made on a 5-star scale, with half-star increments (0.5 stars - 5.0 stars).
#     * Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
df_ratings
# Out:
#           userId  movieId  rating   timestamp
# 0              1        2     3.5  1112486027
# 1              1       29     3.5  1112484676
# 2              1       32     3.5  1112484819
# 3              1       47     3.5  1112484727
# 4              1       50     3.5  1112484580
# 5              1      112     3.5  1094785740
# 6              1      151     4.0  1094785734
# 7              1      223     4.0  1112485573
# 8              1      253     4.0  1112484940
# 9              1      260     4.0  1112484826
# 10             1      293     4.0  1112484703
# 11             1      296     4.0  1112484767
# 12             1      318     4.0  1112484798
# 13             1      337     3.5  1094785709
# 14             1      367     3.5  1112485980
# 15             1      541     4.0  1112484603
# 16             1      589     3.5  1112485557
# 17             1      593     3.5  1112484661
# 18             1      653     3.0  1094785691
# 19             1      919     3.5  1094785621
# 20             1      924     3.5  1094785598
# 21             1     1009     3.5  1112486013
# 22             1     1036     4.0  1112485480
# 23             1     1079     4.0  1094785665
# 24             1     1080     3.5  1112485375
# 25             1     1089     3.5  1112484669
# 26             1     1090     4.0  1112485453
# 27             1     1097     4.0  1112485701
# 28             1     1136     3.5  1112484609
# 29             1     1193     3.5  1112484690
# ...          ...      ...     ...         ...
# 18554132  138493    50872     3.5  1256750388
# 18554133  138493    51086     3.5  1255810566
# 18554134  138493    51662     4.5  1255856908
# 18554135  138493    51884     4.5  1256294768
# 18554136  138493    52579     4.0  1255856957
# 18554137  138493    52975     4.0  1256680293
# 18554138  138493    53123     4.0  1255816320
# 18554139  138493    53125     3.0  1255810649
# 18554140  138493    53322     4.0  1255812146
# 18554141  138493    53464     4.0  1260209920
# 18554142  138493    53996     4.5  1259865104
# 18554143  138493    55269     5.0  1255816088
# 18554144  138493    55814     5.0  1255811181
# 18554145  138493    56757     3.0  1255810698
# 18554146  138493    56801     3.0  1255809988
# 18554147  138493    58879     4.5  1255816798
# 18554148  138493    59315     4.0  1255818138
# 18554149  138493    59725     3.0  1255818078
# 18554150  138493    59784     5.0  1255816901
# 18554151  138493    60069     4.0  1258134687
# 18554152  138493    60816     4.5  1259865163
# 18554153  138493    61160     4.0  1258390537
# 18554154  138493    65682     4.5  1255816373
# 18554155  138493    66762     4.5  1255805408
# 18554156  138493    68319     4.5  1260209720
# 18554157  138493    68954     4.5  1258126920
# 18554158  138493    69526     4.5  1259865108
# 18554159  138493    69644     3.0  1260209457
# 18554160  138493    70286     5.0  1258126944
# 18554161  138493    71619     2.5  1255811136
#
# [18554162 rows x 4 columns]

# %% [markdown]
# Ratings Distribution

# %%
plt.hist(df_ratings['rating'], bins=[0.75, 1.25, 1.75, 2.25, 2.75, 3.25, 3.75, 4.25, 4.75, 5.25])
plt.show()

# %% [markdown]
# Rating Distribution on Timestamps

# %%
df_ratings['datetime'] = pd.to_datetime(df_ratings['timestamp'], unit='s')
plt.hist(df_ratings['datetime'], bins=17)
plt.show()

# %% [markdown]
# Count of userId

# %%
np.unique(df_ratings['userId']).shape[0]
# Out:
# 128722

# %% [markdown]
# Count of movieId

# %%
np.unique(df_ratings['movieId']).shape[0]
# Out:
# 19551

# %% [markdown]
# Covered density

# %%
num_userId = 128722
num_movieId = 19551
density = df_ratings.shape[0] / (num_userId * num_movieId)
print('{} %'.format(density * 100))
# Out:
# 0.7372581625497897 %

# %% [markdown]
# ## movies
#
# Movie titles are entered manually or imported from https://www.themoviedb.org/, and include the year of release in parentheses. Errors and inconsistencies may exist in these titles.

# %%
df_movies
# Out:
#        movieId                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# 13          14                                       Nixon (1995)
# 14          15                            Cutthroat Island (1995)
# 15          16                                      Casino (1995)
# 16          17                       Sense and Sensibility (1995)
# 17          18                                  Four Rooms (1995)
# 18          19              Ace Ventura: When Nature Calls (1995)
# 19          20                                 Money Train (1995)
# 20          21                                  Get Shorty (1995)
# 21          22                                     Copycat (1995)
# 22          23                                   Assassins (1995)
# 23          24                                      Powder (1995)
# 24          25                           Leaving Las Vegas (1995)
# 25          26                                     Othello (1995)
# 26          27                                Now and Then (1995)
# 27          28                                  Persuasion (1995)
# 28          29  City of Lost Children, The (Cité des enfants p...
# 29          30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# ...        ...                                                ...
# 25354   131126                            Erkan & Stefan 3 (2005)
# 25355   131128                                   Flodder 3 (1995)
# 25356   131130            Tom and Jerry: A Nutcracker Tale (2007)
# 25357   131132                Kleines Arschloch - Der Film (1997)
# 25358   131134                            Manta - Der Film (1991)
# 25359   131136                                Girls on Top (2001)
# 25360   131138                                   My Führer (2007)
# 25361   131140                            Stopped on Track (2011)
# 25362   131142                               Voll Normaaal (1994)
# 25363   131144                Werner - Das muss kesseln!!! (1996)
# 25364   131146                      Werner - Volles Rooäää (1999)
# 25365   131148                                  What A Man (2011)
# 25366   131150         7 Dwarves: The Forest Is Not Enough (2006)
# 25367   131152                                 The Fat Spy (1966)
# 25368   131154  Die Bademeister – Weiber, saufen, Leben retten...
# 25369   131156                         Ants in the Pants 2 (2002)
# 25370   131158                                Manta, Manta (1991)
# 25371   131160                  Oscar and the Lady in Pink (2009)
# 25372   131164                               Vietnam in HD (2011)
# 25373   131166                                  WWII IN HD (2009)
# 25374   131237                         What Men Talk About (2010)
# 25375   131239                          Three Quarter Moon (2011)
# 25376   131241                           Ants in the Pants (2000)
# 25377   131243                Werner - Gekotzt wird später (2003)
# 25378   131248                              Brother Bear 2 (2006)
# 25379   131250                              No More School (2000)
# 25380   131252  Forklift Driver Klaus: The First Day on the Jo...
# 25381   131254                       Kein Bund für's Leben (2007)
# 25382   131256                      Feuer, Eis & Dosenbier (2002)
# 25383   131260                                Rentun Ruusu (2001)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# 5                            Action|Crime|Thriller
# 6                                   Comedy|Romance
# 7                               Adventure|Children
# 8                                           Action
# 9                        Action|Adventure|Thriller
# 10                            Comedy|Drama|Romance
# 11                                   Comedy|Horror
# 12                    Adventure|Animation|Children
# 13                                           Drama
# 14                        Action|Adventure|Romance
# 15                                     Crime|Drama
# 16                                   Drama|Romance
# 17                                          Comedy
# 18                                          Comedy
# 19              Action|Comedy|Crime|Drama|Thriller
# 20                           Comedy|Crime|Thriller
# 21             Crime|Drama|Horror|Mystery|Thriller
# 22                           Action|Crime|Thriller
# 23                                    Drama|Sci-Fi
# 24                                   Drama|Romance
# 25                                           Drama
# 26                                  Children|Drama
# 27                                   Drama|Romance
# 28          Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                     Crime|Drama
# ...                                            ...
# 25354                                       Comedy
# 25355                                       Comedy
# 25356                             Animation|Comedy
# 25357                             Animation|Comedy
# 25358                                       Comedy
# 25359                                       Comedy
# 25360                             Comedy|Drama|War
# 25361                                        Drama
# 25362                                       Comedy
# 25363                             Animation|Comedy
# 25364                             Animation|Comedy
# 25365                               Comedy|Romance
# 25366                                       Comedy
# 25367                                       Comedy
# 25368                                       Comedy
# 25369                                       Comedy
# 25370                                       Comedy
# 25371                                        Drama
# 25372                                          War
# 25373                           (no genres listed)
# 25374                                       Comedy
# 25375                                 Comedy|Drama
# 25376                               Comedy|Romance
# 25377                             Animation|Comedy
# 25378  Adventure|Animation|Children|Comedy|Fantasy
# 25379                                       Comedy
# 25380                                Comedy|Horror
# 25381                                       Comedy
# 25382                                       Comedy
# 25383                           (no genres listed)
#
# [25384 rows x 3 columns]

# %%
df_movies_refine = df_movies.copy()
df_movies_refine['year'] = ((df_movies_refine['title'].str.extract(r'\((....)\) *$'))[0].astype('float32'))
df_movies_refine = df_movies_refine.dropna()
df_movies_refine['year'] = df_movies_refine['year'].astype('int32')
df_movies_refine['title'] = (df_movies_refine['title'].str.extract(r'^(.*) \(....\) *$'))[0]
df_movies_refine['genres'] = df_movies_refine['genres'].str.split('|')

df_movies_refine
# Out:
#        movieId                                              title  \
# 0            1                                          Toy Story
# 1            2                                            Jumanji
# 2            3                                   Grumpier Old Men
# 3            4                                  Waiting to Exhale
# 4            5                        Father of the Bride Part II
# 5            6                                               Heat
# 6            7                                            Sabrina
# 7            8                                       Tom and Huck
# 8            9                                       Sudden Death
# 9           10                                          GoldenEye
# 10          11                            American President, The
# 11          12                        Dracula: Dead and Loving It
# 12          13                                              Balto
# 13          14                                              Nixon
# 14          15                                   Cutthroat Island
# 15          16                                             Casino
# 16          17                              Sense and Sensibility
# 17          18                                         Four Rooms
# 18          19                     Ace Ventura: When Nature Calls
# 19          20                                        Money Train
# 20          21                                         Get Shorty
# 21          22                                            Copycat
# 22          23                                          Assassins
# 23          24                                             Powder
# 24          25                                  Leaving Las Vegas
# 25          26                                            Othello
# 26          27                                       Now and Then
# 27          28                                         Persuasion
# 28          29  City of Lost Children, The (Cité des enfants p...
# 29          30      Shanghai Triad (Yao a yao yao dao waipo qiao)
# ...        ...                                                ...
# 25354   131126                                   Erkan & Stefan 3
# 25355   131128                                          Flodder 3
# 25356   131130                   Tom and Jerry: A Nutcracker Tale
# 25357   131132                       Kleines Arschloch - Der Film
# 25358   131134                                   Manta - Der Film
# 25359   131136                                       Girls on Top
# 25360   131138                                          My Führer
# 25361   131140                                   Stopped on Track
# 25362   131142                                      Voll Normaaal
# 25363   131144                       Werner - Das muss kesseln!!!
# 25364   131146                             Werner - Volles Rooäää
# 25365   131148                                         What A Man
# 25366   131150                7 Dwarves: The Forest Is Not Enough
# 25367   131152                                        The Fat Spy
# 25368   131154     Die Bademeister – Weiber, saufen, Leben retten
# 25369   131156                                Ants in the Pants 2
# 25370   131158                                       Manta, Manta
# 25371   131160                         Oscar and the Lady in Pink
# 25372   131164                                      Vietnam in HD
# 25373   131166                                         WWII IN HD
# 25374   131237                                What Men Talk About
# 25375   131239                                 Three Quarter Moon
# 25376   131241                                  Ants in the Pants
# 25377   131243                       Werner - Gekotzt wird später
# 25378   131248                                     Brother Bear 2
# 25379   131250                                     No More School
# 25380   131252    Forklift Driver Klaus: The First Day on the Job
# 25381   131254                              Kein Bund für's Leben
# 25382   131256                             Feuer, Eis & Dosenbier
# 25383   131260                                       Rentun Ruusu
#
#                                                   genres  year
# 0      [Adventure, Animation, Children, Comedy, Fantasy]  1995
# 1                         [Adventure, Children, Fantasy]  1995
# 2                                      [Comedy, Romance]  1995
# 3                               [Comedy, Drama, Romance]  1995
# 4                                               [Comedy]  1995
# 5                              [Action, Crime, Thriller]  1995
# 6                                      [Comedy, Romance]  1995
# 7                                  [Adventure, Children]  1995
# 8                                               [Action]  1995
# 9                          [Action, Adventure, Thriller]  1995
# 10                              [Comedy, Drama, Romance]  1995
# 11                                      [Comedy, Horror]  1995
# 12                      [Adventure, Animation, Children]  1995
# 13                                               [Drama]  1995
# 14                          [Action, Adventure, Romance]  1995
# 15                                        [Crime, Drama]  1995
# 16                                      [Drama, Romance]  1995
# 17                                              [Comedy]  1995
# 18                                              [Comedy]  1995
# 19              [Action, Comedy, Crime, Drama, Thriller]  1995
# 20                             [Comedy, Crime, Thriller]  1995
# 21             [Crime, Drama, Horror, Mystery, Thriller]  1995
# 22                             [Action, Crime, Thriller]  1995
# 23                                       [Drama, Sci-Fi]  1995
# 24                                      [Drama, Romance]  1995
# 25                                               [Drama]  1995
# 26                                     [Children, Drama]  1995
# 27                                      [Drama, Romance]  1995
# 28          [Adventure, Drama, Fantasy, Mystery, Sci-Fi]  1995
# 29                                        [Crime, Drama]  1995
# ...                                                  ...   ...
# 25354                                           [Comedy]  2005
# 25355                                           [Comedy]  1995
# 25356                                [Animation, Comedy]  2007
# 25357                                [Animation, Comedy]  1997
# 25358                                           [Comedy]  1991
# 25359                                           [Comedy]  2001
# 25360                               [Comedy, Drama, War]  2007
# 25361                                            [Drama]  2011
# 25362                                           [Comedy]  1994
# 25363                                [Animation, Comedy]  1996
# 25364                                [Animation, Comedy]  1999
# 25365                                  [Comedy, Romance]  2011
# 25366                                           [Comedy]  2006
# 25367                                           [Comedy]  1966
# 25368                                           [Comedy]  1999
# 25369                                           [Comedy]  2002
# 25370                                           [Comedy]  1991
# 25371                                            [Drama]  2009
# 25372                                              [War]  2011
# 25373                               [(no genres listed)]  2009
# 25374                                           [Comedy]  2010
# 25375                                    [Comedy, Drama]  2011
# 25376                                  [Comedy, Romance]  2000
# 25377                                [Animation, Comedy]  2003
# 25378  [Adventure, Animation, Children, Comedy, Fantasy]  2006
# 25379                                           [Comedy]  2000
# 25380                                   [Comedy, Horror]  2001
# 25381                                           [Comedy]  2007
# 25382                                           [Comedy]  2002
# 25383                               [(no genres listed)]  2001
#
# [25384 rows x 4 columns]

# %% [markdown]
# Movie distribution on years

# %%
plt.hist(df_movies_refine.year, bins=20)
plt.show()

# %% [markdown]
# Count of genres

# %%
genre_count = dict()
for index, series in df_movies_refine.iterrows():
    for genre in series['genres']:
        genre_count[genre] = genre_count.get(genre, 0) + 1
pprint(genre_count)
# Out:
# {'(no genres listed)': 205,
#  'Action': 3265,
#  'Adventure': 2176,
#  'Animation': 939,
#  'Children': 1065,
#  'Comedy': 7851,
#  'Crime': 2765,
#  'Documentary': 2157,
#  'Drama': 12541,
#  'Fantasy': 1324,
#  'Film-Noir': 329,
#  'Horror': 2446,
#  'IMAX': 149,
#  'Musical': 1002,
#  'Mystery': 1430,
#  'Romance': 3927,
#  'Sci-Fi': 1611,
#  'Thriller': 3853,
#  'War': 1160,
#  'Western': 664}

# %% [markdown]
# Kinds of genres

# %%
len(genre_count)
# Out:
# 20

# %% [markdown]
# ## genome
#
# This data set includes a current copy of the Tag Genome.
#
# [genome-paper](http://files.grouplens.org/papers/tag_genome.pdf)
#
# The tag genome is a data structure that contains tag relevance scores for movies. The structure is a dense matrix: each movie in the genome has a value for every tag in the genome.
#
# As described in [this article](http://files.grouplens.org/papers/tag_genome.pdf), the tag genome encodes how strongly movies exhibit particular properties represented by tags (atmospheric, thought-provoking, realistic, etc.). The tag genome was computed using a machine learning algorithm on user-contributed content including tags, ratings, and textual reviews.

# %%
df_genome
# Out:
#           movieId  tagId  relevance                 tag
# 0               1      1    0.02500                 007
# 1               1      2    0.02500        007 (series)
# 2               1      3    0.05775        18th century
# 3               1      4    0.09675               1920s
# 4               1      5    0.14675               1930s
# 5               1      6    0.21700               1950s
# 6               1      7    0.06700               1960s
# 7               1      8    0.26275               1970s
# 8               1      9    0.26200               1980s
# 9               1     10    0.03200        19th century
# 10              1     11    0.57700                  3d
# 11              1     12    0.11625                70mm
# 12              1     13    0.18800                 80s
# 13              1     14    0.00800                9/11
# 14              1     15    0.03675             aardman
# 15              1     16    0.28175     aardman studios
# 16              1     17    0.00700            abortion
# 17              1     18    0.11050              absurd
# 18              1     19    0.67050              action
# 19              1     20    0.18450       action packed
# 20              1     21    0.33025          adaptation
# 21              1     22    0.28250   adapted from:book
# 22              1     23    0.05700  adapted from:comic
# 23              1     24    0.01550   adapted from:game
# 24              1     25    0.08500           addiction
# 25              1     26    0.08100         adolescence
# 26              1     27    0.19500            adoption
# 27              1     28    0.07150            adultery
# 28              1     29    0.89200           adventure
# 29              1     30    0.67625        affectionate
# ...           ...    ...        ...                 ...
# 11052114   118890   1099    0.01475       waste of time
# 11052115   118890   1100    0.02500   watch the credits
# 11052116   118890   1101    0.26825             weapons
# 11052117   118890   1102    0.01950             wedding
# 11052118   118890   1103    0.25025                weed
# 11052119   118890   1104    0.23050               weird
# 11052120   118890   1105    0.02175            werewolf
# 11052121   118890   1106    0.00525          werewolves
# 11052122   118890   1107    0.01650             western
# 11052123   118890   1108    0.14000           whimsical
# 11052124   118890   1109    0.16250          wilderness
# 11052125   118890   1110    0.34200                wine
# 11052126   118890   1111    0.03950             wistful
# 11052127   118890   1112    0.02875               witch
# 11052128   118890   1113    0.11775             witches
# 11052129   118890   1114    0.73550               witty
# 11052130   118890   1115    0.04225             wizards
# 11052131   118890   1116    0.08425               women
# 11052132   118890   1117    0.27925       working class
# 11052133   118890   1118    0.25250           workplace
# 11052134   118890   1119    0.12725      world politics
# 11052135   118890   1120    0.15875         world war i
# 11052136   118890   1121    0.07150        world war ii
# 11052137   118890   1122    0.14925       writer's life
# 11052138   118890   1123    0.17750             writers
# 11052139   118890   1124    0.14525             writing
# 11052140   118890   1125    0.03225               wuxia
# 11052141   118890   1126    0.07275                wwii
# 11052142   118890   1127    0.07050              zombie
# 11052143   118890   1128    0.02050             zombies
#
# [11052144 rows x 4 columns]

# %% [markdown]
# Genome tag relevance distribution

# %%
plt.hist(df_genome['relevance'])
plt.show()

# %% [markdown]
# ## tags
#
# All tags are contained in the file tags.csv. Each line of this file after the header row represents one tag applied to one movie by one user, and has the following format:
#
# userId,movieId,tag,timestamp
#
# The lines within this file are ordered first by userId, then, within user, by movieId.
#
# Tags are user-generated metadata about movies. Each tag is typically a single word or short phrase. The meaning, value, and purpose of a particular tag is determined by each user.
#
# Timestamps represent seconds since midnight Coordinated Universal Time (UTC) of January 1, 1970.

# %%
df_tags
# Out:
#         userId  movieId                                             tag  \
# 0           18     4141                                     Mark Waters
# 1           65    27803              Oscar (Best Foreign Language Film)
# 2           65    27866                                     New Zealand
# 3           65    48082                                         surreal
# 4           65    48082                                         unusual
# 5           65    58652                                            cute
# 6           65    58652                                       emotional
# 7           65    58652                             girls who play boys
# 8           65    58652                                    Stephen Chow
# 9          121      778                                     dark comedy
# 10         121      778                                           drugs
# 11         121      778                 Nudity (Full Frontal - Notable)
# 12         121      778                           Nudity (Full Frontal)
# 13         121     1288                               Christopher Guest
# 14         121     1288                                          comedy
# 15         121     1288                                  music business
# 16         121     1288                                   rock and roll
# 17         121     1288                                          satire
# 18         121     1288                                           witty
# 19         121     2706                      Nudity (Topless - Notable)
# 20         121     2706                                Nudity (Topless)
# 21         121     2706                                       sexuality
# 22         121     2706                                     teen comedy
# 23         121     4718                                Nudity (Topless)
# 24         121     4718                                       sexuality
# 25         121     5283                                   College Humor
# 26         121     5283                                Nudity (Topless)
# 27         121     5283                                               R
# 28         121     5283                                   Ryan Reynolds
# 29         121     5283                                      Teen movie
# ...        ...      ...                                             ...
# 332922  138436    71129                          FEWER than 300 ratings
# 332923  138436    71282                              liberal propaganda
# 332924  138436    72167                                   disappointing
# 332925  138436    72167                                       vigilante
# 332926  138436    72395                                     child abuse
# 332927  138436    72395                                  teen pregnancy
# 332928  138436    72998                                   incredible 3D
# 332929  138436    72998                                        too long
# 332930  138436    73323                                          sequel
# 332931  138436    74458                                 Martin Scorsese
# 332932  138436    74458                                        too long
# 332933  138436    76175                                              3d
# 332934  138436    76175                                      3D version
# 332935  138436    76175                                  existentialism
# 332936  138436    76175                                     Liam Neeson
# 332937  138436    76175                                      philosophy
# 332938  138436    76251                                    Nicolas Cage
# 332939  138436    76251                                       vigilante
# 332940  138436    77307                                     cat killing
# 332941  138436    77307                                          incest
# 332942  138436    77359                          FEWER than 300 ratings
# 332943  138436    78218                                         torture
# 332944  138436    78266                                    Adrien Brody
# 332945  138436    79293  Bechdel Test:Pass (technically but not really)
# 332946  138436    79553                                        bad plot
# 332947  138436    81932                                        big hair
# 332948  138436    81932                                   Mark Wahlberg
# 332949  138436    81932                                            pigs
# 332950  138436    81932                                    prostitution
# 332951  138472      923                                   rise to power
#
#          timestamp
# 0       1240597180
# 1       1305008715
# 2       1304957153
# 3       1304958354
# 4       1304958359
# 5       1304957612
# 6       1304957608
# 7       1304957403
# 8       1304957388
# 9       1300852846
# 10      1300852844
# 11      1300852839
# 12      1300852841
# 13      1301640559
# 14      1301640506
# 15      1301640523
# 16      1301640495
# 17      1301640497
# 18      1301640500
# 19      1300767681
# 20      1300767684
# 21      1300767692
# 22      1300767688
# 23      1300767714
# 24      1300767716
# 25      1300767768
# 26      1300767757
# 27      1300767759
# 28      1300767755
# 29      1300767763
# ...            ...
# 332922  1267354347
# 332923  1258242688
# 332924  1267030978
# 332925  1260222358
# 332926  1260773747
# 332927  1260773750
# 332928  1261943100
# 332929  1261943115
# 332930  1276045156
# 332931  1279936705
# 332932  1279936716
# 332933  1276241049
# 332934  1276241054
# 332935  1276241073
# 332936  1276241058
# 332937  1276241068
# 332938  1276307986
# 332939  1276307983
# 332940  1282921748
# 332941  1282921740
# 332942  1298754971
# 332943  1283391099
# 332944  1276712379
# 332945  1282314189
# 332946  1284430430
# 332947  1298754654
# 332948  1298754636
# 332949  1298754658
# 332950  1298754620
# 332951  1194037967
#
# [332952 rows x 4 columns]

# %% [markdown]
# Tags distribution on time

# %%
df_tags['datetime'] = pd.to_datetime(df_tags['timestamp'], unit='s')
plt.hist(df_tags['datetime'], bins=20)
plt.show()
